# %%
# --- Mount Google Drive ---
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My Drive/CS 495 DataScience Capstone Project/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/CS 495 DataScience Capstone Project

# %%
# --- Imports ---
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, LSTM, GRU, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# --- Configuration ---
full_data = True
vocab_limit = 15000
enc_max_len = 64
dec_max_len = 150
max_dec_input_length = dec_max_len - 1
embedding_dim = 128
units = 128
batch = 64
repeat = 20
patience = 20
custom_learning_rate = 5e-5
adam_optimizer = Adam(learning_rate=custom_learning_rate)
val_ratio = 0.2
min_delta = 0.01

# %%
# --- Load Dataset ---
train_df = pd.read_csv("prompt_synopsis_train.csv")
if not full_data:
    train_df = train_df.sample(n=1000, random_state=42).reset_index(drop=True)

# --- Clean Text ---
def clean_text(text):
    return text.lower().strip().replace('\n', ' ')

for col in ['prompt', 'synopsis']:
    train_df[col] = train_df[col].astype(str).apply(clean_text)

# %%
# --- Tokenizer ---
PAD_ID = 0
OOV_ID = 1
BOS_ID = 2
EOS_ID = 3
NUM_SPECIAL_TOKENS_RESERVED = 4
num_words_to_fit = vocab_limit - NUM_SPECIAL_TOKENS_RESERVED

tokenizer = Tokenizer(num_words=num_words_to_fit, oov_token='<OOV>', filters='')
tokenizer.fit_on_texts(train_df['prompt'].tolist() + train_df['synopsis'].tolist())

new_word_index = {
    "<PAD>": PAD_ID,
    "<OOV>": OOV_ID,
    "<BOS>": BOS_ID,
    "<EOS>": EOS_ID
}
new_index_word = {v: k for k, v in new_word_index.items()}
next_available_id = NUM_SPECIAL_TOKENS_RESERVED
content_words_assigned = 0

for word, original_id in sorted(tokenizer.word_index.items(), key=lambda item: item[1]):
    if word in new_word_index:
        continue
    if content_words_assigned < num_words_to_fit:
        new_word_index[word] = next_available_id
        new_index_word[next_available_id] = word
        next_available_id += 1
        content_words_assigned += 1
    else:
        break

tokenizer.word_index = new_word_index
tokenizer.index_word = new_index_word
vocab_size = vocab_limit

with open("tokenizer_LSTM-GRU_15k.pkl", "wb") as f:
    pickle.dump(tokenizer, f)

# %%
# --- Sequence Tokenization ---
input_seqs = tokenizer.texts_to_sequences(train_df['prompt'])
output_seqs = tokenizer.texts_to_sequences(train_df['synopsis'])

target_augmented = [[BOS_ID] + seq + [EOS_ID] for seq in output_seqs]
decoder_input_ids = [seq[:-1] for seq in target_augmented]
decoder_target_ids = [seq[1:] for seq in target_augmented]

encoder_input_data = pad_sequences(input_seqs, maxlen=enc_max_len, padding='post', truncating='post', value=PAD_ID)
decoder_input_data = pad_sequences(decoder_input_ids, maxlen=max_dec_input_length, padding='post', truncating='post', value=PAD_ID)
decoder_target_data = pad_sequences(decoder_target_ids, maxlen=max_dec_input_length, padding='post', truncating='post', value=PAD_ID)
decoder_target_data = np.expand_dims(decoder_target_data, axis=-1)

# %%
# --- Train/Validation Split ---
X_train_enc, X_val_enc, X_train_dec, X_val_dec, y_train, y_val = train_test_split(
    encoder_input_data, decoder_input_data, decoder_target_data, test_size=val_ratio, random_state=42
)

train_inputs = (X_train_enc, X_train_dec)
val_inputs = [X_val_enc, X_val_dec]

# %%
# --- LSTM Encoder + GRU Decoder Model ---
encoder_inputs = Input(shape=(enc_max_len,), name='encoder_input_lstm')
encoder_embedding = Embedding(vocab_size, embedding_dim, mask_zero=True)(encoder_inputs)
_, enc_h, enc_c = LSTM(units, return_state=True, unroll=True, name='encoder_lstm')(encoder_embedding)
encoder_state = enc_h

decoder_inputs = Input(shape=(max_dec_input_length,), name='decoder_input_gru')
decoder_embedding = Embedding(vocab_size, embedding_dim, mask_zero=True)(decoder_inputs)
decoder_gru, _ = GRU(units, return_sequences=True, return_state=True, unroll=True, name='decoder_gru')(decoder_embedding, initial_state=encoder_state)
decoder_dense = Dense(vocab_size, activation='softmax')(decoder_gru)

model = Model(inputs=[encoder_inputs, decoder_inputs], outputs=decoder_dense)
model.compile(optimizer=adam_optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# --- Summary ---
print("LSTM-GRU Model Summary (15k Vocab)")
model.summary()
# Out:
# LSTM-GRU Model Summary (15k Vocab)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ encoder_input_lstm  │ (None, 64)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_input_gru   │ (None, 149)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 64, 128)   │  1,920,000 │ encoder_input_ls… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal           │ (None, 64)        │          0 │ encoder_input_ls… │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, 149, 128)  │  1,920,000 │ decoder_input_gr… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_lstm (LSTM) │ [(None, 128),     │    131,584 │ embedding[0][0],  │
# │                     │ (None, 128),      │            │ not_equal[0][0]   │
# │                     │ (None, 128)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_gru (GRU)   │ [(None, 149,      │     99,072 │ embedding_1[0][0… │
# │                     │ 128), (None,      │            │ encoder_lstm[0][… │
# │                     │ 128)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 149,       │  1,935,000 │ decoder_gru[0][0] │
# │                     │ 15000)            │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 6,005,656 (22.91 MB)
#  Trainable params: 6,005,656 (22.91 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# --- Callbacks ---
model_path = "lstm_gru_model_15k.keras"
checkpoint_cb = ModelCheckpoint(model_path, save_best_only=True, monitor='val_loss', mode='min', verbose=1)
earlystop_cb = EarlyStopping(monitor='val_loss', patience=patience, min_delta=min_delta, restore_best_weights=True, verbose=1)

# %%
# --- Training ---
history = model.fit(
    train_inputs,
    y_train,
    batch_size=batch,
    epochs=repeat,
    validation_data=(val_inputs, y_val),
    callbacks=[checkpoint_cb, earlystop_cb],
    verbose=1
)
# Out:
# Epoch 1/20
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.0451 - loss: 8.4488
# Epoch 1: val_loss improved from inf to 6.62605, saving model to lstm_gru_model_15k.keras
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 242s 168ms/step - accuracy: 0.0451 - loss: 8.4476 - val_accuracy: 0.0534 - val_loss: 6.6260
# Epoch 2/20
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0541 - loss: 6.6128
# Epoch 2: val_loss improved from 6.62605 to 6.61554, saving model to lstm_gru_model_15k.keras
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - accuracy: 0.0541 - loss: 6.6128 - val_accuracy: 0.0534 - val_loss: 6.6155
# Epoch 3/20
# 753/754 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0541 - loss: 6.6064
# Epoch 3: val_loss improved from 6.61554 to 6.61344, saving model to lstm_gru_model_15k.keras
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - accuracy: 0.0541 - loss: 6.6064 - val_accuracy: 0.0534 - val_loss: 6.6134
# Epoch 4/20
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0540 - loss: 6.6101
# Epoch 4: val_loss improved from 6.61344 to 6.58831, saving model to lstm_gru_model_15k.keras
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - accuracy: 0.0540 - loss: 6.6101 - val_accuracy: 0.0534 - val_loss: 6.5883
# Epoch 5/20
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0542 - loss: 6.5510
# Epoch 5: val_loss improved from 6.58831 to 6.45958, saving model to lstm_gru_model_15k.keras
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - accuracy: 0.0542 - loss: 6.5509 - val_accuracy: 0.0658 - val_loss: 6.4596
# Epoch 6/20
# 753/754 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0678 - loss: 6.4281
# Epoch 6: val_loss improved from 6.45958 to 6.35560, saving model to lstm_gru_model_15k.keras
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - accuracy: 0.0678 - loss: 6.4280 - val_accuracy: 0.0719 - val_loss: 6.3556
# Epoch 7/20
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0734 - loss: 6.3264
# Epoch 7: val_loss improved from 6.35560 to 6.26179, saving model to lstm_gru_model_15k.keras
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - accuracy: 0.0734 - loss: 6.3263 - val_accuracy: 0.0755 - val_loss: 6.2618
# Epoch 8/20
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0794 - loss: 6.2252
# Epoch 8: val_loss improved from 6.26179 to 6.16387, saving model to lstm_gru_model_15k.keras
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - accuracy: 0.0794 - loss: 6.2252 - val_accuracy: 0.0843 - val_loss: 6.1639
# Epoch 9/20
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0854 - loss: 6.1367
# Epoch 9: val_loss improved from 6.16387 to 6.08515, saving model to lstm_gru_model_15k.keras
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - accuracy: 0.0854 - loss: 6.1366 - val_accuracy: 0.0854 - val_loss: 6.0851
# Epoch 10/20
# 753/754 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0870 - loss: 6.0586
# Epoch 10: val_loss improved from 6.08515 to 6.01394, saving model to lstm_gru_model_15k.keras
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - accuracy: 0.0870 - loss: 6.0586 - val_accuracy: 0.0882 - val_loss: 6.0139
# Epoch 11/20
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0898 - loss: 5.9849
# Epoch 11: val_loss improved from 6.01394 to 5.94767, saving model to lstm_gru_model_15k.keras
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - accuracy: 0.0898 - loss: 5.9849 - val_accuracy: 0.0910 - val_loss: 5.9477
# Epoch 12/20
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0927 - loss: 5.9189
# Epoch 12: val_loss improved from 5.94767 to 5.88428, saving model to lstm_gru_model_15k.keras
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - accuracy: 0.0927 - loss: 5.9188 - val_accuracy: 0.0932 - val_loss: 5.8843
# Epoch 13/20
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0948 - loss: 5.8558
# Epoch 13: val_loss improved from 5.88428 to 5.82658, saving model to lstm_gru_model_15k.keras
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - accuracy: 0.0948 - loss: 5.8557 - val_accuracy: 0.0953 - val_loss: 5.8266
# Epoch 14/20
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0974 - loss: 5.7979
# Epoch 14: val_loss improved from 5.82658 to 5.77245, saving model to lstm_gru_model_15k.keras
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - accuracy: 0.0974 - loss: 5.7979 - val_accuracy: 0.0970 - val_loss: 5.7725
# Epoch 15/20
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0985 - loss: 5.7450
# Epoch 15: val_loss improved from 5.77245 to 5.72279, saving model to lstm_gru_model_15k.keras
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - accuracy: 0.0985 - loss: 5.7449 - val_accuracy: 0.0989 - val_loss: 5.7228
# Epoch 16/20
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.1008 - loss: 5.6925
# Epoch 16: val_loss improved from 5.72279 to 5.67679, saving model to lstm_gru_model_15k.keras
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - accuracy: 0.1008 - loss: 5.6924 - val_accuracy: 0.1011 - val_loss: 5.6768
# Epoch 17/20
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.1027 - loss: 5.6458
# Epoch 17: val_loss improved from 5.67679 to 5.63406, saving model to lstm_gru_model_15k.keras
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - accuracy: 0.1027 - loss: 5.6458 - val_accuracy: 0.1032 - val_loss: 5.6341
# Epoch 18/20
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.1051 - loss: 5.6051
# Epoch 18: val_loss improved from 5.63406 to 5.59419, saving model to lstm_gru_model_15k.keras
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - accuracy: 0.1051 - loss: 5.6051 - val_accuracy: 0.1051 - val_loss: 5.5942
# Epoch 19/20
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.1070 - loss: 5.5661
# Epoch 19: val_loss improved from 5.59419 to 5.55695, saving model to lstm_gru_model_15k.keras
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - accuracy: 0.1070 - loss: 5.5660 - val_accuracy: 0.1068 - val_loss: 5.5569
# Epoch 20/20
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.1080 - loss: 5.5272
# Epoch 20: val_loss improved from 5.55695 to 5.52158, saving model to lstm_gru_model_15k.keras
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - accuracy: 0.1080 - loss: 5.5272 - val_accuracy: 0.1083 - val_loss: 5.5216
# Restoring model weights from the end of the best epoch: 20.

# %%
# --- Plot Loss ---
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('LSTM-GRU Loss over Epochs (15k Vocab)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# --- Evaluation ---
model.load_weights(model_path)
val_loss, val_acc = model.evaluate(val_inputs, y_val, verbose=0)
perplexity = np.exp(val_loss)
print(f"LSTM-GRU Model Perplexity (15k Vocab): {perplexity:.2f}")
# Out:
# LSTM-GRU Model Perplexity (15k Vocab): 249.89
